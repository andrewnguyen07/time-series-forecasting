# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#data source: https://www.bgc-jena.mpg.de/wetter/

df = pd.read_csv("weather.csv")

# %%
df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.07.2020 00:10:00    983.85     16.17    290.67        10.63   69.68
# 1  01.07.2020 00:20:00    983.72     15.90    290.41        10.66   71.02
# 2  01.07.2020 00:30:00    983.65     15.69    290.21        10.65   71.92
# 3  01.07.2020 00:40:00    983.58     15.56    290.08        10.68   72.68
# 4  01.07.2020 00:50:00    983.58     15.64    290.16        10.68   72.31
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  ...  wv (m/s)  \
# 0         18.41         12.83          5.58       8.15  ...      1.27
# 1         18.09         12.85          5.24       8.17  ...      1.91
# 2         17.85         12.84          5.01       8.16  ...      1.30
# 3         17.70         12.87          4.84       8.18  ...      1.20
# 4         17.80         12.87          4.93       8.18  ...      0.89
#
#    max. wv (m/s)  wd (deg)  rain (mm)  raining (s)  SWDR (W/m≤)  \
# 0           2.12     194.0        0.0            0          0.0
# 1           2.84     197.1        0.0            0          0.0
# 2           2.05     213.3        0.0            0          0.0
# 3           2.16     222.9        0.0            0          0.0
# 4           2.60     220.3        0.0            0          0.0
#
#    PAR (µmol/m≤/s)  max. PAR (µmol/m≤/s)  Tlog (degC)  CO2 (ppm)
# 0              0.0                   0.0        25.08      422.1
# 1              0.0                   0.0        25.03      422.9
# 2              0.0                   0.0        24.97      423.8
# 3              0.0                   0.0        24.90      424.6
# 4              0.0                   0.0        24.83      423.5
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (14031, 22)

# %%
#subsampling the dataset from 10-min intervals to 1-hour intervals:

df = df[5::6].reset_index(drop=True)

# %%
df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.07.2020 01:00:00    983.48     15.55    290.08        10.71   72.88
# 1  01.07.2020 02:00:00    983.35     15.48    290.02        10.88   74.02
# 2  01.07.2020 03:00:00    983.21     15.50    290.05        10.97   74.38
# 3  01.07.2020 04:00:00    983.22     15.74    290.29        11.02   73.48
# 4  01.07.2020 05:00:00    983.32     15.86    290.40        11.28   74.19
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  ...  wv (m/s)  \
# 0         17.69         12.89          4.80       8.20  ...      0.85
# 1         17.61         13.04          4.58       8.29  ...      1.77
# 2         17.64         13.12          4.52       8.34  ...      1.37
# 3         17.91         13.16          4.75       8.37  ...      1.74
# 4         18.05         13.39          4.66       8.51  ...      1.68
#
#    max. wv (m/s)  wd (deg)  rain (mm)  raining (s)  SWDR (W/m≤)  \
# 0           1.84     205.9        0.0            0         0.00
# 1           2.46     214.4        0.0            0         0.00
# 2           2.68     212.4        0.0            0         0.00
# 3           2.43     202.7        0.0            0         0.00
# 4           2.51     204.4        0.0            0        49.51
#
#    PAR (µmol/m≤/s)  max. PAR (µmol/m≤/s)  Tlog (degC)  CO2 (ppm)
# 0             0.00                  0.00        24.77      425.0
# 1             0.00                  0.00        24.46      428.0
# 2             0.00                  0.00        24.18      425.3
# 3             5.09                  7.45        24.00      422.4
# 4            91.06                103.73        24.24      428.8
#
# [5 rows x 22 columns]

# %%
df.describe().transpose()
# Out:
#                        count         mean         std      min        25%  \
# p (mbar)              2338.0   988.553991    6.722326   964.64   985.0725
# T (degC)              2338.0    18.100372    5.592306     2.83    14.2725
# Tpot (K)              2338.0   292.212399    5.586209   278.05   288.3125
# Tdew (degC)           2338.0    11.060573    3.623319     2.83     8.2600
# rh (%)                2338.0    67.367844   21.155475    23.60    49.7600
# VPmax (mbar)          2338.0    21.953332    7.919531     7.49    16.2925
# VPact (mbar)          2338.0    13.538683    3.329580     7.49    10.9300
# VPdef (mbar)          2338.0     8.414491    7.594570     0.00     2.3600
# sh (g/kg)             2338.0     8.567344    2.123527     4.80     6.9000
# H2OC (mmol/mol)       2338.0    13.697956    3.375918     7.69    11.0500
# rho (g/m**3)          2338.0  1176.701839   23.844583  1108.74  1159.5600
# wv (m/s)              2338.0     1.838738    1.345905     0.15     0.8800
# max. wv (m/s)         2338.0     3.129397    2.154569     0.29     1.5800
# wd (deg)              2338.0   175.183914   86.677287     0.19   116.4250
# rain (mm)             2338.0     0.016168    0.179869     0.00     0.0000
# raining (s)           2338.0    18.502994   96.039591     0.00     0.0000
# SWDR (W/m≤)           2338.0   185.697806  248.020799     0.00     0.0000
# PAR (µmol/m≤/s)       2338.0   371.533323  491.643898     0.00     0.0000
# max. PAR (µmol/m≤/s)  2338.0   431.224410  774.161059 -9999.00     0.0000
# Tlog (degC)           2338.0    29.276694    6.084317    14.87    24.7425
# CO2 (ppm)             2338.0   410.163730  373.890287 -9999.00   405.3000
#
#                            50%        75%      max
# p (mbar)               989.725   992.5700  1002.29
# T (degC)                18.110    21.7900    34.58
# Tpot (K)               292.070   295.9175   308.75
# Tdew (degC)             10.910    13.6700    20.13
# rh (%)                  67.625    85.6750   100.00
# VPmax (mbar)            20.820    26.1400    55.00
# VPact (mbar)            13.065    15.6675    23.61
# VPdef (mbar)             6.505    12.6500    41.16
# sh (g/kg)                8.280     9.9100    14.99
# H2OC (mmol/mol)         13.250    15.8400    23.88
# rho (g/m**3)          1176.345  1193.1000  1246.67
# wv (m/s)                 1.480     2.3900     9.41
# max. wv (m/s)            2.510     4.1100    14.87
# wd (deg)               195.300   232.0250   359.90
# rain (mm)                0.000     0.0000     5.40
# raining (s)              0.000     0.0000   600.00
# SWDR (W/m≤)             38.430   322.9150  1007.07
# PAR (µmol/m≤/s)         85.035   647.6700  2011.52
# max. PAR (µmol/m≤/s)    96.265   794.7550  2486.30
# Tlog (degC)             29.070    33.3275    49.03
# CO2 (ppm)              415.450   436.5000   515.80

# %%
#1. EDA & Data Preparation

# %%
#convert date string to datetime type and remove from dataframe

datetime = pd.to_datetime(df['Date Time'])
df = df.drop(columns=['Date Time'])

# %%
#convert wind velocity, max wind velocity and wind direction to wind vector

df['wd_rad'] = df['wd (deg)']*np.pi/180 #convert wd to radians

df['wx'] = df['wv (m/s)']*np.cos(df['wd_rad']) #calculate the wind x and y components
df['wy'] = df['wv (m/s)']*np.sin(df['wd_rad'])

df['max wx'] = df['max. wv (m/s)']*np.cos(df['wd_rad']) #calculate the wind x and y components
df['max wy'] = df['max. wv (m/s)']*np.sin(df['wd_rad'])

# %%
df = df.drop(columns=['wd (deg)', 'wv (m/s)', 'max. wv (m/s)'])

# %%
#replace extreme values

df.loc[df['max. PAR (µmol/m≤/s)'] == -9999] = 0
df.loc[df['CO2 (ppm)'] == -9999] = 0

# %%
#split the dataset

n = len(df)

train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

# %%
#normalize the dataset

from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
ss.fit(train_df)

train_df = ss.transform(train_df)
val_df = ss.transform(val_df)
test_df = ss.transform(test_df)

# %%
#visualize the entire dataset to check extreme outliers

df_scaled = pd.DataFrame(ss.fit_transform(df), columns=df.columns)

plt.figure(figsize=(15,6))
ax = sns.violinplot(data=df_scaled)
_ = ax.set_xticklabels(df.keys(), rotation=90)

# %%
#2. Neural Network Modelling (Multiple Parallel Series)

# %%
#split the sequence

def split_sequences(dataset, n_steps):
    x, y = list(), list()
    for i in range(len(dataset)):
        end = i + n_steps
        if end > len(dataset)-1:
            break
        seq_x, seq_y = dataset[i:end], dataset[end]
        x.append(seq_x)
        y.append(seq_y)
    return np.array(x), np.array(y)

n_steps = 24 #1-day interval

x_train, y_train = split_sequences(train_df, n_steps=n_steps)
x_val, y_val = split_sequences(val_df, n_steps=n_steps)
x_test, y_test = split_sequences(test_df, n_steps=n_steps)

# %%
#2.1. Vanilla LSTM
#2.2. Stacked LSTM
#2.3. Bidirectional LSTM

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping

# %%
n_features = x_train.shape[2]

# %%
#2.1. Vanilla LSTM

lstm = Sequential()

lstm.add(LSTM(64, activation='relu', kernel_initializer='he_normal', input_shape=(n_steps, n_features),
             return_sequences=True))
lstm.add(Dense(n_features))
lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 24, 64)            22528
# _________________________________________________________________
# dense (Dense)                (None, 24, 23)            1495
# =================================================================
# Total params: 24,023
# Trainable params: 24,023
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm.compile(optimizer='adam', loss = 'mse', metrics=['mae'])

# %%
epochs=20

history = lstm.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=epochs, batch_size=1, verbose=2)
# Out:
# Epoch 1/20
# 1612/1612 - 13s - loss: 1.0032 - mae: 0.6172 - val_loss: 0.7791 - val_mae: 0.5803
# Epoch 2/20
# 1612/1612 - 13s - loss: 0.7092 - mae: 0.5099 - val_loss: 0.6200 - val_mae: 0.4842
# Epoch 3/20
# 1612/1612 - 15s - loss: 0.6313 - mae: 0.4582 - val_loss: 0.6106 - val_mae: 0.4873
# Epoch 4/20
# 1612/1612 - 12s - loss: 0.5905 - mae: 0.4322 - val_loss: 0.5520 - val_mae: 0.4349
# Epoch 5/20
# 1612/1612 - 12s - loss: 0.5624 - mae: 0.4167 - val_loss: 0.5495 - val_mae: 0.4401
# Epoch 6/20
# 1612/1612 - 13s - loss: 0.5424 - mae: 0.4037 - val_loss: 0.5621 - val_mae: 0.4380
# Epoch 7/20
# 1612/1612 - 12s - loss: 0.5246 - mae: 0.3931 - val_loss: 0.5609 - val_mae: 0.4331
# Epoch 8/20
# 1612/1612 - 12s - loss: 0.5086 - mae: 0.3837 - val_loss: 0.5540 - val_mae: 0.4353
# Epoch 9/20
# 1612/1612 - 12s - loss: 0.5002 - mae: 0.3826 - val_loss: 0.5574 - val_mae: 0.4291
# Epoch 10/20
# 1612/1612 - 12s - loss: 0.4754 - mae: 0.3691 - val_loss: 0.5598 - val_mae: 0.4337
# Epoch 11/20
# 1612/1612 - 13s - loss: 0.4572 - mae: 0.3670 - val_loss: 0.5411 - val_mae: 0.4255
# Epoch 12/20
# 1612/1612 - 13s - loss: 0.4417 - mae: 0.3604 - val_loss: 0.6595 - val_mae: 0.4342
# Epoch 13/20
# 1612/1612 - 13s - loss: 0.4509 - mae: 0.3584 - val_loss: 0.7379 - val_mae: 0.4771
# Epoch 14/20
# 1612/1612 - 13s - loss: 0.4048 - mae: 0.3491 - val_loss: 1.2455 - val_mae: 0.4742
# Epoch 15/20
# 1612/1612 - 12s - loss: 0.4459 - mae: 0.3585 - val_loss: 0.5747 - val_mae: 0.4386
# Epoch 16/20
# 1612/1612 - 12s - loss: 0.4201 - mae: 0.3468 - val_loss: 0.6018 - val_mae: 0.4391
# Epoch 17/20
# 1612/1612 - 12s - loss: 0.3846 - mae: 0.3404 - val_loss: 0.5488 - val_mae: 0.4269
# Epoch 18/20
# 1612/1612 - 14s - loss: 0.3766 - mae: 0.3353 - val_loss: 0.6164 - val_mae: 0.4443
# Epoch 19/20
# 1612/1612 - 13s - loss: 0.3607 - mae: 0.3359 - val_loss: 1.1038 - val_mae: 0.4687
# Epoch 20/20
# 1612/1612 - 14s - loss: 0.4078 - mae: 0.3386 - val_loss: 0.6632 - val_mae: 0.4518

# %%
from matplotlib.ticker import FormatStrFormatter

plt.figure(figsize=(10,4))
ax = plt.subplot()

ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))

plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.legend(['Training MAE', 'Validation MAE'])
plt.title('Training and Validation MAE')
plt.show()

# %%
#2.2. Stacked LSTM

lstm2 = Sequential()

lstm2.add(LSTM(64, activation='relu', kernel_initializer='he_normal', input_shape=(n_steps, n_features),
             return_sequences=True))
lstm2.add(LSTM(32, activation='relu', kernel_initializer='he_normal',
             return_sequences=True))
lstm2.add(Dense(n_features))
lstm2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 24, 64)            22528
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 24, 32)            12416
# _________________________________________________________________
# dense_2 (Dense)              (None, 24, 23)            759
# =================================================================
# Total params: 35,703
# Trainable params: 35,703
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm2.compile(optimizer='adam', loss = 'mse', metrics=['mae'])

# %%
history2 = lstm2.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=epochs, batch_size=1, verbose=2)
# Out:
# Epoch 1/20
# 1612/1612 - 21s - loss: 0.8990 - mae: 0.6042 - val_loss: 0.6626 - val_mae: 0.5186
# Epoch 2/20
# 1612/1612 - 20s - loss: 0.6761 - mae: 0.4820 - val_loss: 0.5979 - val_mae: 0.4655
# Epoch 3/20
# 1612/1612 - 18s - loss: 0.6072 - mae: 0.4389 - val_loss: 0.5833 - val_mae: 0.4613
# Epoch 4/20
# 1612/1612 - 18s - loss: 0.5715 - mae: 0.4153 - val_loss: 0.5398 - val_mae: 0.4240
# Epoch 5/20
# 1612/1612 - 18s - loss: 0.5453 - mae: 0.3990 - val_loss: 0.5755 - val_mae: 0.4508
# Epoch 6/20
# 1612/1612 - 18s - loss: 0.5234 - mae: 0.3853 - val_loss: 0.5815 - val_mae: 0.4550
# Epoch 7/20
# 1612/1612 - 18s - loss: 0.5089 - mae: 0.3838 - val_loss: 0.5542 - val_mae: 0.4267
# Epoch 8/20
# 1612/1612 - 18s - loss: 0.4839 - mae: 0.3649 - val_loss: 0.5953 - val_mae: 0.4613
# Epoch 9/20
# 1612/1612 - 18s - loss: 0.4733 - mae: 0.3631 - val_loss: 0.5722 - val_mae: 0.4354
# Epoch 10/20
# 1612/1612 - 18s - loss: 0.4483 - mae: 0.3519 - val_loss: 0.5968 - val_mae: 0.4456
# Epoch 11/20
# 1612/1612 - 17s - loss: 0.4857 - mae: 0.3652 - val_loss: 0.6726 - val_mae: 0.4905
# Epoch 12/20
# 1612/1612 - 19s - loss: 0.4417 - mae: 0.3488 - val_loss: 0.5683 - val_mae: 0.4332
# Epoch 13/20
# 1612/1612 - 18s - loss: 0.4155 - mae: 0.3417 - val_loss: 0.5896 - val_mae: 0.4460
# Epoch 14/20
# 1612/1612 - 18s - loss: 0.3886 - mae: 0.3381 - val_loss: 0.6322 - val_mae: 0.4601
# Epoch 15/20
# 1612/1612 - 18s - loss: 0.3875 - mae: 0.3349 - val_loss: 0.6220 - val_mae: 0.4559
# Epoch 16/20
# 1612/1612 - 17s - loss: 0.3635 - mae: 0.3309 - val_loss: 0.5880 - val_mae: 0.4474
# Epoch 17/20
# 1612/1612 - 18s - loss: 0.3965 - mae: 0.3305 - val_loss: 0.6282 - val_mae: 0.4524
# Epoch 18/20
# 1612/1612 - 17s - loss: 0.3348 - mae: 0.3214 - val_loss: 0.6992 - val_mae: 0.4747
# Epoch 19/20
# 1612/1612 - 19s - loss: 0.3536 - mae: 0.3153 - val_loss: 0.5906 - val_mae: 0.4450
# Epoch 20/20
# 1612/1612 - 18s - loss: 0.3648 - mae: 0.3195 - val_loss: 0.7108 - val_mae: 0.4537

# %%
plt.figure(figsize=(10,4))
ax = plt.subplot()

ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))

plt.plot(history2.history['mae'])
plt.plot(history2.history['val_mae'])
plt.legend(['Training MAE', 'Validation MAE'])
plt.title('Training and Validation MAE')
plt.show()

# %%
#2.3. Bidirectional LSTM

# %%
lstm3 = Sequential()

lstm3.add(Bidirectional(LSTM(64, activation = 'relu', kernel_initializer = 'he_normal',
                             return_sequences=True, input_shape = (n_steps, n_features))))
lstm3.add(Dense(n_features))

# %%
lstm3.compile(optimizer='adam', loss = 'mse', metrics=['mae'])

# %%
history3 = lstm3.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=epochs, batch_size=1, verbose=2)
# Out:
# Epoch 1/20
# 1612/1612 - 17s - loss: 0.8087 - mae: 0.5543 - val_loss: 0.6065 - val_mae: 0.4667
# Epoch 2/20
# 1612/1612 - 17s - loss: 0.5421 - mae: 0.3989 - val_loss: 0.4777 - val_mae: 0.3954
# Epoch 3/20
# 1612/1612 - 17s - loss: 0.4816 - mae: 0.3530 - val_loss: 0.4755 - val_mae: 0.4044
# Epoch 4/20
# 1612/1612 - 17s - loss: 0.4565 - mae: 0.3354 - val_loss: 0.4067 - val_mae: 0.3477
# Epoch 5/20
# 1612/1612 - 17s - loss: 0.4332 - mae: 0.3195 - val_loss: 0.3747 - val_mae: 0.3167
# Epoch 6/20
# 1612/1612 - 20s - loss: 0.4216 - mae: 0.3058 - val_loss: 0.3706 - val_mae: 0.3248
# Epoch 7/20
# 1612/1612 - 30s - loss: 0.4357 - mae: 0.3027 - val_loss: 0.3532 - val_mae: 0.3159
# Epoch 8/20
# 1612/1612 - 21s - loss: 0.3941 - mae: 0.2900 - val_loss: 0.3619 - val_mae: 0.3155
# Epoch 9/20
# 1612/1612 - 18s - loss: 0.3685 - mae: 0.2861 - val_loss: 0.3815 - val_mae: 0.3220
# Epoch 10/20
# 1612/1612 - 19s - loss: 0.3625 - mae: 0.2822 - val_loss: 0.3534 - val_mae: 0.3112
# Epoch 11/20
# 1612/1612 - 19s - loss: 0.3613 - mae: 0.2871 - val_loss: 0.3529 - val_mae: 0.3031
# Epoch 12/20
# 1612/1612 - 18s - loss: 0.3577 - mae: 0.2791 - val_loss: 0.3488 - val_mae: 0.3061
# Epoch 13/20
# 1612/1612 - 18s - loss: 0.3258 - mae: 0.2768 - val_loss: 0.3895 - val_mae: 0.3037
# Epoch 14/20
# 1612/1612 - 18s - loss: 0.3202 - mae: 0.2730 - val_loss: 0.3574 - val_mae: 0.2942
# Epoch 15/20
# 1612/1612 - 18s - loss: 0.3550 - mae: 0.2729 - val_loss: 0.3409 - val_mae: 0.2870
# Epoch 16/20
# 1612/1612 - 18s - loss: 0.3051 - mae: 0.2643 - val_loss: 0.3405 - val_mae: 0.2919
# Epoch 17/20
# 1612/1612 - 18s - loss: 0.2848 - mae: 0.2624 - val_loss: 0.3576 - val_mae: 0.3095
# Epoch 18/20
# 1612/1612 - 18s - loss: 0.3324 - mae: 0.2670 - val_loss: 0.3350 - val_mae: 0.2874
# Epoch 19/20
# 1612/1612 - 18s - loss: 0.2564 - mae: 0.2578 - val_loss: 0.3591 - val_mae: 0.3046
# Epoch 20/20
# 1612/1612 - 18s - loss: 0.2379 - mae: 0.2559 - val_loss: 0.3893 - val_mae: 0.2997

# %%
plt.figure(figsize=(10,4))
ax = plt.subplot()

ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))

plt.plot(history3.history['mae'])
plt.plot(history3.history['val_mae'])
plt.legend(['Training MAE', 'Validation MAE'])
plt.title('Training and Validation MAE')
plt.show()
